# %%
import math
for number in range(1,50):
    if number%2==0:
        print(math.sqrt(number))
# Out:
# 1.4142135623730951
# 2.0
# 2.449489742783178
# 2.8284271247461903
# 3.1622776601683795
# 3.4641016151377544
# 3.7416573867739413
# 4.0
# 4.242640687119285
# 4.47213595499958
# 4.69041575982343
# 4.898979485566356
# 5.0990195135927845
# 5.291502622129181
# 5.477225575051661
# 5.656854249492381
# 5.830951894845301
# 6.0
# 6.164414002968976
# 6.324555320336759
# 6.48074069840786
# 6.6332495807108
# 6.782329983125268
# 6.928203230275509

# %%
import numpy as np
Mac=list(np.random.randint(low=1,high=8,size=10))
print(Mac)
# Out:
# [4, 7, 5, 3, 3, 1, 1, 3, 3, 7]

# %%
sum(Mac)
# Out:
# 37

# %%
def multiply(mylist):
    result=1
    for x in mylist:
        result=result * x
    return result  
multiply(Mac)
# Out:
# 79380

# %%
def collatz(number):
        if number%2==0:
            print(number/2)
        else:
            print(number*3+1)
        
       
collatz(3)
# Out:
# 10
