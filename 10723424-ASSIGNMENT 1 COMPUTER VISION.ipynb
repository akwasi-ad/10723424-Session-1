# %%
import math
for number in range(1,50):
    if number%2==0:
        print(math.sqrt(number))
# Out:
# 1.4142135623730951
# 2.0
# 2.449489742783178
# 2.8284271247461903
# 3.1622776601683795
# 3.4641016151377544
# 3.7416573867739413
# 4.0
# 4.242640687119285
# 4.47213595499958
# 4.69041575982343
# 4.898979485566356
# 5.0990195135927845
# 5.291502622129181
# 5.477225575051661
# 5.656854249492381
# 5.830951894845301
# 6.0
# 6.164414002968976
# 6.324555320336759
# 6.48074069840786
# 6.6332495807108
# 6.782329983125268
# 6.928203230275509

# %%
import numpy as np
Mac=list(np.random.randint(low=1,high=8,size=10))
print(Mac)
# Out:
# [3, 2, 7, 1, 7, 2, 7, 3, 7, 7]

# %%
sum(Mac)
# Out:
# 37

# %%
def multiply(mylist):
    result=1
    for x in mylist:
        result=result * x
    return result  
multiply(Mac)
# Out:
# 79380

# %%
def collatz(number):
    while number >1:
        if number%2==0:
            number=number//2
        else:
            number=number*3+1
        print(number) 
       
enter=int(input("Enter Number for the collatz sequence : "))
collatz(enter)
# Out:
# Enter Number for the collatz sequence : 6634965637465347869573465378465973465637846534763756734675637657435
# 19904896912396043608720396135397920396913539604291270204026912972306
# 9952448456198021804360198067698960198456769802145635102013456486153
# 29857345368594065413080594203096880595370309406436905306040369458460
# 14928672684297032706540297101548440297685154703218452653020184729230
# 7464336342148516353270148550774220148842577351609226326510092364615
# 22393009026445549059810445652322660446527732054827678979530277093846
# 11196504513222774529905222826161330223263866027413839489765138546923
# 33589513539668323589715668478483990669791598082241518469295415640770
# 16794756769834161794857834239241995334895799041120759234647707820385
# 50384270309502485384573502717725986004687397123362277703943123461156
# 25192135154751242692286751358862993002343698561681138851971561730578
# 12596067577375621346143375679431496501171849280840569425985780865289
# ...
